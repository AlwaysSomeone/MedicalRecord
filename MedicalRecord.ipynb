# %%
# !ls
# Out:
# datalab

# %%
# !git clone https://github.com/AlwaysSomeone/MedicalRecord.git
# !ls
# Out:
# Cloning into 'MedicalRecord'...
# remote: Counting objects: 37, done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 37 (delta 6), reused 32 (delta 4), pack-reused 0
# Unpacking objects: 100% (37/37), done.
# datalab  MedicalRecord

# %%
# !cp -r MedicalRecord/* ./
# !ls
# Out:
# data	 initial.py	network.py   prediction.py  test_GRU.py
# datalab  MedicalRecord	origin_data  README.md	    train_GRU.py

# %%
# !python initial.py
# Out:
# reading word embedding data...
# reading relation to id
# reading train data...
# reading test data ...
# organizing train data
# organizing test data
# reading training data
# seprating train data
# seperating test all data

# %%
# !python train_GRU.py
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# reading wordembedding
# reading training data
# 2018-03-30 12:53:00.106197: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-03-30 12:53:00.106660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-03-30 12:53:00.106724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# ...

# %%
# !python prediction.py
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2018-03-30 12:59:41.367688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-03-30 12:59:41.368011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-03-30 12:59:41.368048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# ...
